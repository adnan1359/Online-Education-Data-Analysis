# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
online_edu = pd.read_csv("online_education.csv")
online_edu
# Out:
#      Education Level Institution Type  Gender  Age  Device IT Student  \
# 0         University          Private    Male   23     Tab         No
# 1         University          Private  Female   23  Mobile         No
# 2            College           Public  Female   18  Mobile         No
# 3             School          Private  Female   11  Mobile         No
# 4             School          Private  Female   18  Mobile         No
# ...              ...              ...     ...  ...     ...        ...
# 1200         College          Private  Female   18  Mobile         No
# 1201         College          Private  Female   18  Mobile         No
# 1202          School          Private    Male   11  Mobile         No
# 1203         College          Private  Female   18  Mobile         No
# 1204          School          Private  Female   11  Mobile         No
#
#      Location Financial Condition Internet Type Network Type Flexibility Level
# ...

# %%
online_edu.head()
# Out:
#   Education Level Institution Type  Gender  Age  Device IT Student Location  \
# 0      University          Private    Male   23     Tab         No     Town
# 1      University          Private  Female   23  Mobile         No     Town
# 2         College           Public  Female   18  Mobile         No     Town
# 3          School          Private  Female   11  Mobile         No     Town
# 4          School          Private  Female   18  Mobile         No     Town
#
#   Financial Condition Internet Type Network Type Flexibility Level
# 0                 Mid          Wifi           4G          Moderate
# 1                 Mid   Mobile Data           4G          Moderate
# 2                 Mid          Wifi           4G          Moderate
# 3                 Mid   Mobile Data           4G          Moderate
# 4                Poor   Mobile Data           3G               Low

# %%
online_edu.sample(5)
# Out:
#     Education Level Institution Type  Gender  Age  Device IT Student Location  \
# 392         College          Private  Female   18  Mobile         No    Rural
# 460          School          Private    Male   11  Mobile         No     Town
# 703          School           Public  Female    9  Mobile         No     Town
# 148      University          Private  Female   23  Mobile         No     Town
# 949      University          Private    Male   23  Mobile         No    Rural
#
#     Financial Condition Internet Type Network Type Flexibility Level
# 392                 Mid          Wifi           4G               Low
# 460                 Mid   Mobile Data           4G          Moderate
# 703                Rich   Mobile Data           4G               Low
# 148                Poor          Wifi           4G               Low
# 949                 Mid          Wifi           4G          Moderate

# %%
online_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education Level      1205 non-null   object
#  1   Institution Type     1205 non-null   object
#  2   Gender               1205 non-null   object
#  3   Age                  1205 non-null   int64
#  4   Device               1205 non-null   object
#  5   IT Student           1205 non-null   object
#  6   Location             1205 non-null   object
#  7   Financial Condition  1205 non-null   object
#  8   Internet Type        1205 non-null   object
#  9   Network Type         1205 non-null   object
#  10  Flexibility Level    1205 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 103.7+ KB

# %%
online_edu.describe()
# Out:
#                Age
# count  1205.000000
# mean     17.065560
# std       5.830369
# min       9.000000
# 25%      11.000000
# 50%      18.000000
# 75%      23.000000
# max      27.000000

# %%
institution_types = online_edu["Education Level"].value_counts()
institution_types
# Out:
# School        530
# University    456
# College       219
# Name: Education Level, dtype: int64

# %%
sb.countplot(x = 'Education Level', data = online_edu)

plt.title("Distribution of Institutions")
plt.xlabel("Number of Students")
plt.ylabel("Institutions")

plt.show()

# %%
online_edu
# Out:
#      Education Level Institution Type  Gender  Age  Device IT Student  \
# 0         University          Private    Male   23     Tab         No
# 1         University          Private  Female   23  Mobile         No
# 2            College           Public  Female   18  Mobile         No
# 3             School          Private  Female   11  Mobile         No
# 4             School          Private  Female   18  Mobile         No
# ...              ...              ...     ...  ...     ...        ...
# 1200         College          Private  Female   18  Mobile         No
# 1201         College          Private  Female   18  Mobile         No
# 1202          School          Private    Male   11  Mobile         No
# 1203         College          Private  Female   18  Mobile         No
# 1204          School          Private  Female   11  Mobile         No
#
#      Location Financial Condition Internet Type Network Type Flexibility Level
# ...

# %%
online_edu[['Institution Type', 'Education Level']].value_counts()
# Out:
# Institution Type  Education Level
# Private           School             430
#                   University         301
# Public            University         155
#                   College            127
#                   School             100
# Private           College             92
# dtype: int64

# %%
devices = online_edu.Device.value_counts()

# %%
sb.countplot(online_edu.Device)

plt.title("Distribution of Devices")
plt.xlabel("Devices")
plt.ylabel("Number of Devices")

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
online_edu
# Out:
#      Education Level Institution Type  Gender  Age  Device IT Student  \
# 0         University          Private    Male   23     Tab         No
# 1         University          Private  Female   23  Mobile         No
# 2            College           Public  Female   18  Mobile         No
# 3             School          Private  Female   11  Mobile         No
# 4             School          Private  Female   18  Mobile         No
# ...              ...              ...     ...  ...     ...        ...
# 1200         College          Private  Female   18  Mobile         No
# 1201         College          Private  Female   18  Mobile         No
# 1202          School          Private    Male   11  Mobile         No
# 1203         College          Private  Female   18  Mobile         No
# 1204          School          Private  Female   11  Mobile         No
#
#      Location Financial Condition Internet Type Network Type Flexibility Level
# ...

# %%
online_edu[["Education Level", "Internet Type"]].value_counts()
# Out:
# Education Level  Internet Type
# School           Mobile Data      395
# University       Wifi             255
#                  Mobile Data      201
# School           Wifi             135
# College          Wifi             120
#                  Mobile Data       99
# dtype: int64

# %%
sb.countplot(x = 'Internet Type', data = online_edu)
